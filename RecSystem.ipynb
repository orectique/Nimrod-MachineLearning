# %%
import pandas as pd

# %%
products = pd.read_csv('title_category.csv')
products.head()
# Out:
#    Unnamed: 0   ProductId          UserId  Score  \
# 0           0  B000E7L2R4  A1MZYO9TZK0BBI      5
# 1           1  B0001PB9FE  A3HDKO7OW0QNK4      5
# 2           2  B0009XLVG0  A2725IB4YY9JEB      5
# 3           3  B0009XLVG0   A327PCT23YH90      1
# 4           4  B0001PB9FY  A3HDKO7OW0QNK4      5
#
#                                              Content  Sentiment  \
# 0  Yay Barley Right now I'm mostly just sprouting...          1
# 1  The Best Hot Sauce in the World I don't know i...          1
# 2  My cats LOVE this "diet" food better than thei...          1
# 3  My Cats Are Not Fans of the New Food My cats h...         -1
# 4  The Best Hot Sauce in the World I don't know i...          1
#
#                                                Title         Category
# 0         Organic Sprouting Barley Grass Seed - 9 lb    Lawn & Garden
# 1  Original Tequila Picante Gourmet de Inclan - 5 OZ   Pantry Staples
# 2  Felidae Dry Cat Food for Senior and Overweight...             Cats
# ...

# %%
prods = set(products.ProductId)
people = set(products.UserId)

df_prods = pd.DataFrame(columns= ['ProductId', 'Content', 'Title'])
df_users = pd.DataFrame(columns= ['UserId', 'Content'])

for prod in prods:
    temp = products

# %%
print('bob')
# Out:
# bob
