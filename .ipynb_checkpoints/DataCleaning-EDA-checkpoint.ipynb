# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from collections import Counter

# %%
prods = []
titles = []
file = open('titles.txt', 'r', encoding='utf-8', errors= 'ignore')
for row in file:
    prods.append(row[:10])
    titles.append(row[11:-1])
file.close()

df_prods = pd.DataFrame({'ProductId': prods, 'Title': titles})

df_prods.head()

# %%
df = pd.read_csv('Reviews.csv')
df.describe()

# %%
df.head()

# %%
df['Content'] = df.Summary + ' ' + df.Text # Merging columns to make NLP easier

df = df.drop(['Summary', 'Text', 'HelpfulnessNumerator', 'HelpfulnessDenominator', 'ProfileName', 'Time', 'Id'], axis = 1).reset_index(drop = True) #Removing unnecessary columns

df['Sentiment'] = df.Score.apply(lambda x: -1 if x < 3 else (0 if x==3 else 1)) #Creating a column of categorical sentiments based on

# %%
df = df.merge(df_prods, how = 'inner')

df.describe()
# Out:
#                Score      Sentiment
# count  101646.000000  101646.000000
# mean        4.239931       0.659996
# std         1.297328       0.707823
# min         1.000000      -1.000000
# 25%         4.000000       1.000000
# 50%         5.000000       1.000000
# 75%         5.000000       1.000000
# max         5.000000       1.000000

# %%
df.head()
# Out:
#     ProductId          UserId  Score  \
# 0  B000E7L2R4  A1MZYO9TZK0BBI      5
# 1  B0001PB9FE  A3HDKO7OW0QNK4      5
# 2  B0009XLVG0  A2725IB4YY9JEB      5
# 3  B0009XLVG0   A327PCT23YH90      1
# 4  B0001PB9FY  A3HDKO7OW0QNK4      5
#
#                                              Content  Sentiment  \
# 0  Yay Barley Right now I'm mostly just sprouting...          1
# 1  The Best Hot Sauce in the World I don't know i...          1
# 2  My cats LOVE this "diet" food better than thei...          1
# 3  My Cats Are Not Fans of the New Food My cats h...         -1
# 4  The Best Hot Sauce in the World I don't know i...          1
#
#                                                Title
# 0         Organic Sprouting Barley Grass Seed - 9 lb
# 1  Original Tequila Picante Gourmet de Inclan - 5 OZ
# 2  Felidae Dry Cat Food for Senior and Overweight...
# 3  Felidae Dry Cat Food for Senior and Overweight...
# 4  Original Tequila Picante Gourmet de Inclan - C...

# %%
user_count = df.UserId.value_counts()

user_count.plot.hist(bins = 5, range = (0, 100))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
product_count = df.ProductId.value_counts()

product_count.plot.hist(bins = 5, range = (0, 100))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# # Work in progress - Proceed with caution

# %%
prods = []
categories = []
arr =[]
file = open('categories.txt', 'r', encoding='utf-8', errors= 'ignore')
i = 0
for row in file:
    arr.append(row)

# %%
arr
# Out:
# ['B0027DQHA0\n',
#  '  Movies & TV, TV\n',
#  '  Music, Classical\n',
#  '0756400120\n',
#  '  Books, Literature & Fiction, Anthologies & Literary Collections, General\n',
#  '  Books, Literature & Fiction, United States\n',
#  '  Books, Science Fiction & Fantasy, Science Fiction, Anthologies\n',
#  '  Books, Science Fiction & Fantasy, Science Fiction, Short Stories\n',
#  'B0000012D5\n',
#  '  Music, Blues\n',
#  '  Music, Pop\n',
#  '  Music, R&B\n',
#  'B00024YAOQ\n',
#  '  Books, Business & Investing, Business Life, Motivation & Self-Improvement\n',
#  '068413263X\n',
#  '  Books\n',
#  'B000BUGXAU\n',
#  '  Pet Supplies, Fish & Aquatic Pets, Aquariums\n',
#  'B0000A0QE6\n',
#  '  Clothing & Accessories, Men, Tops & Tees, Dress Shirts\n',
#  'B0007YMWC8\n',
#  '  Movies & TV, Movies\n',
#  'B0000A0QE2\n',
#  '  Clothing & Accessories, Men, Tops & Tees, Dress Shirts\n',
#  'B000GG6ENK\n',
#  '  Health & Personal Care, Nutrition & Wellness, Vitamins & Supplements, Vitamins & Multivitamins\n',
#  'B0001WPQ6U\n',
#  '  Sports & Outdoors, Fan Shop, Sports Souvenirs, Helmets, Mini Helmets\n',
#  'B0000012D9\n',
#  '  Music, Pop\n',
#  '  Music, R&B\n',
#  '1592851827\n',
#  '  Books, Biographies & Memoirs, Memoirs\n',
#  '  Books, Health, Fitness & Dieting, Addiction & Recovery, Substance Abuse\n',
#  '  Books, Humor & Entertainment\n',
#  '  Books, Self-Help, Motivational\n',
#  'B000BPMKMA\n',
#  '  Movies & TV, Movies\n',
#  'B0002052FQ\n',
#  '  Shoes, Women, Fashion Sneakers\n',
#  'B000Q9SXBS\n',
#  '  Patio, Lawn & Garden, Gardening, Plants, Seeds & Bulbs, Vegetables\n',
#  'B0001WOUKS\n',
#  '  Books, Literature & Fiction, Contemporary\n',
#  'B000MJKLAI\n',
#  '  Sports & Outdoors, Boating & Water Sports, Boating, Docking & Anchoring Equipment, Boat Fenders\n',
#  'B000GFLK3U\n',
#  '  Music, World Music\n',
#  'B0000C2LF3\n',
#  '  Clothing & Accessories, Men, Tops & Tees, Polos\n',
#  'B0000061P6\n',
#  '  Music, Classical\n',
#  '0825455138\n',
#  "  Books, Children's Books, Humor\n",
#  "  Books, Children's Books, Literature & Fiction, Religious Fiction, Christian\n",
#  "  Books, Children's Books, Religions, Christianity\n",
#  'B0000C2LF7\n',
#  '  Clothing & Accessories, Men, Tops & Tees, Polos\n',
#  'B000JCQTE0\n',
#  '  Toys & Games, Hobbies, Radio Control, Boats & Watercraft\n',
#  '0738865486\n',
#  '  Books, Literature & Fiction\n',
#  '  Books, Science Fiction & Fantasy, Science Fiction\n',
#  '  Books, Teens\n',
#  'B0006V0BA2\n',
#  '  Clothing & Accessories, Women, Intimates, Panties, G-Strings, Thongs & Tangas\n',
#  'B000GABE04\n',
#  '  Home & Kitchen, Vacuums & Floor Care, Carpet Cleaners\n',
#  '1400047900\n',
#  '  Books, Business & Investing, Investing, Introduction\n',
#  'B000FNYKGW\n',
#  '  Sports & Outdoors, Fan Shop, Home & Garden, Furniture, Folding Chairs\n',
#  '0963022210\n',
#  '  Books, Arts & Photography, History & Criticism\n',
#  '  Books, Business & Investing, Job Hunting & Careers, Guides\n',
#  '  Books, Business & Investing, Popular Economics\n',
#  '  Books, Business & Investing, Small Business & Entrepreneurship, Marketing\n',
#  '  Books, Education & Reference, Writing, Research & Publishing Guides, Writing, Writing Skills\n',
#  '  Books, Politics & Social Sciences, Social Sciences, Communication & Media Studies\n',
#  '0867163119\n',
#  '  Books, Christian Books & Bibles, Catholicism, Inspirational\n',
#  '  Books, Christian Books & Bibles, Protestantism, Pentecostal\n',
#  '  Books, Christian Books & Bibles, Worship & Devotion, Charismatic\n',
#  '  Books, Religion & Spirituality, Spirituality, Inspirational\n',
#  'B0002QNNPQ\n',
#  '  Beauty, Makeup, Nails, Nail Polish\n',
#  'B001R6EXIG\n',
#  '  Amazon Instant Video\n',
#  'B00002SFL4\n',
#  '  Video Games, PC, Games, Action\n',
#  'B00089UP12\n',
#  '  Books, Politics & Social Sciences, Philosophy, Epistemology\n',
#  'B00004UAM2\n',
#  '  Music, Jazz\n',
#  '  Music, Pop\n',
#  'B00004UAM6\n',
#  '  Music, Dance & Electronic\n',
#  '  Music, Pop\n',
#  '0962832308\n',
#  '  Books, New, Used & Rental Textbooks\n',
#  'B000067J0S\n',
#  '  Movies & TV, Movies\n',
#  '1583968903\n',
#  '  Books, Self-Help, New Age\n',
#  '  Books, Self-Help, Relationships, Love & Romance\n',
#  'B0000006YY\n',
#  '  Music, Classical\n',
#  '  Music, Miscellaneous\n',
#  'B0000D91IK\n',
#  '  Movies & TV, Movies\n',
#  'B000H8XPO8\n',
#  '  Automotive, Exterior Accessories, Lights & Lighting Accessories\n',
#  '  Automotive, Replacement Parts, Lighting & Electrical, Lighting, Lighting Assemblies, Replacement Headlight Assemblies\n',
#  '1556591101\n',
#  '  Books, Literature & Fiction, Poetry, American\n',
#  'B000JWE01E\n',
#  '  Books\n',
#  'B0009J8DHE\n',
#  '  Music, Rap & Hip-Hop\n',
#  '0550102574\n',
#  '  Books, Education & Reference, Dictionaries & Thesauruses\n',
#  '  Books, Education & Reference, Foreign Language Study & Reference\n',
#  '  Books, New, Used & Rental Textbooks, Reference, Dictionaries\n',
#  'B0000006YI\n',
#  '  Music, Christian\n',
#  '  Music, Classical\n',
#  '  Music, Dance & Electronic\n',
#  '  Music, Miscellaneous\n',
#  '0764221566\n',
#  '  Books, Christian Books & Bibles, Literature & Fiction, Fiction\n',
#  '  Books, Christian Books & Bibles, Literature & Fiction, Romance\n',
#  '  Books, Literature & Fiction, Contemporary\n',
#  '  Books, Literature & Fiction, Genre Fiction, Family Saga\n',
#  '  Books, Religion & Spirituality, Fiction, Historical\n',
#  '  Books, Religion & Spirituality, Fiction, Romance\n',
#  '  Books, Romance\n',
#  '0763192678\n',
#  '  Books\n',
#  'B0006BN0QO\n',
#  '  Books\n',
#  'B000FLLVC0\n',
#  '  Health & Personal Care, Nutrition & Wellness, Vitamins & Supplements, Herbal Supplements\n',
#  'B000FOV226\n',
#  '  All Electronics\n',
#  'B000A1A9KA\n',
#  '  Sports & Outdoors, Cycling, Tires & Tubes, Tubes\n',
#  '0396083668\n',
#  '  Books, Humor & Entertainment, Puzzles & Games, Gambling\n',
#  'B000FKPDZ2\n',
#  '  Movies & TV, Movies\n',
#  'B000067J0O\n',
#  '  Movies & TV, Movies\n',
#  'B0000006YM\n',
#  '  Music, Classical\n',
#  '0809139294\n',
#  '  Books, Christian Books & Bibles, Theology\n',
#  '  Books, Education & Reference\n',
#  '  Books, Religion & Spirituality, Religious Studies, Theology\n',
#  'B000PT19YW\n',
#  '  Home & Kitchen, Kitchen & Dining, Small Appliances, Coffee, Tea & Espresso Appliances, Electric Kettles\n',
#  'B000Q3T78W\n',
#  '  Health & Personal Care, Health Care, Stimulants\n',
#  '0060167769\n',
#  '  Books, History, Americas, United States, State & Local\n',
#  '  Books, Politics & Social Sciences, Politics & Government, International & World Politics, Asian\n',
#  'B000067J0G\n',
#  '  Movies & TV, Movies\n',
#  'B000067J0C\n',
#  '  Movies & TV, TV\n',
#  '  Music, Country\n',
#  '  Music, Pop\n',
#  '  Music, Rock\n',
#  'B000GKE5S2\n',
#  '  Video Games, More Systems, Xbox, Hardware, Accessories\n',
#  'B0000006YA\n',
#  '  Music, Christian\n',
#  '  Music, Classical\n',
#  '  Music, Folk\n',
#  '  Music, Miscellaneous\n',
#  '  Music, Pop\n',
#  '0807408158\n',
#  '  Books, New, Used & Rental Textbooks, Humanities, Religious Studies\n',
#  '  Books, Religion & Spirituality, Judaism, Sacred Writings, Talmud\n',
#  '0879308060\n',
#  '  Books, Arts & Photography, Music, Instruments, Guitar\n',
#  '  Books, Arts & Photography, Music, Reference\n',
#  '  Books, Arts & Photography, Music, Theory, Composition & Performance, Appreciation\n',
#  '  Books, Arts & Photography, Music, Theory, Composition & Performance, Instruction & Study\n',
#  '  Books, Arts & Photography, Music, Theory, Composition & Performance, Techniques\n',
#  '  Books, Education & Reference\n',
#  '  Books, Humor & Entertainment\n',
#  'B0001GWB64\n',
#  '  Music, Hard Rock & Metal\n',
#  '  Music, Pop\n',
#  '  Music, Rock\n',
#  '1845960793\n',
#  '  Books, Biographies & Memoirs, True Accounts, True Crime\n',
#  '  Books, Politics & Social Sciences, Social Sciences, Criminology\n',
#  '0870697404\n',
#  '  Books, Education & Reference\n',
#  '  Books, Professional & Technical, Engineering, Electrical & Electronics\n',
#  'B000PXVDMG\n',
#  '  Tools & Home Improvement, Lighting & Ceiling Fans, Lamps & Shades, Floor Lamps\n',
#  'B0000061PZ\n',
#  '  Music, Latin Music\n',
#  '  Music, World Music\n',
#  '0553264885\n',
#  '  Books, Literature & Fiction, Genre Fiction, Historical\n',
#  '  Books, Literature & Fiction, Genre Fiction, Westerns\n',
#  '  Books, Science & Math, Biological Sciences, Zoology\n',
#  'B0000012DA\n',
#  '  Music, Blues\n',
#  '  Music, Pop\n',
#  '  Music, R&B\n',
#  'B000JTFNEA\n',
#  '  Home & Kitchen, Bath, Towels, Bath Towels\n',
#  '  Home & Kitchen, Bath, Towels, Towel Sets\n',
#  'B0000A0QEB\n',
#  '  Clothing & Accessories, Men, Tops & Tees, Dress Shirts\n',
#  'B0000A0QEJ\n',
#  '  Clothing & Accessories, Men, Tops & Tees, Dress Shirts\n',
#  'B0000012DI\n',
#  '  Music, Blues\n',
#  '  Music, Pop\n',
#  '  Music, R&B\n',
#  'B0000C2LFS\n',
#  '  Clothing & Accessories, Men, Tops & Tees, Polos\n',
#  '0877791287\n',
#  '  Books, Business & Investing, International, Exports & Imports\n',
#  '  Books, Business & Investing, Skills, Communications\n',
#  "  Books, Computers & Technology, Business & Management, Manager's Guides to Computing\n",
#  '  Books, Education & Reference\n',
#  '  Books, Professional & Technical, Accounting & Finance, International\n',
#  '0449910245\n',
#  '  Books, Health, Fitness & Dieting, Psychology & Counseling\n',
#  '  Books, Parenting & Relationships, Family Relationships, Parent & Adult Child\n',
#  '  Books, Self-Help, Relationships, Interpersonal Relations\n',
#  'B000GR0HNM\n',
#  '  Books\n',
#  'B0009JN8NI\n',
#  '  Home & Kitchen, Furniture, Bedroom Furniture, Futons, Futon Frames\n',
#  'B000FI4R2E\n',
#  '  Baby Products, Nursery, Furniture, Nursery Storage & Organization, Step Stools\n',
#  'B0002F4Y2S\n',
#  '  Musical Instruments, Instrument Accessories, Brass Accessories, Mutes, Trombone\n',
#  'B00014D7OG\n',
#  "  Health & Personal Care, Health Care, Women's Health, Menopause\n",
#  'B000EHJF2I\n',
#  '  Clothing & Accessories, Accessories\n',
#  '  Sports & Outdoors, Fan Shop, Bags, Packs & Accessories, Wallets\n',
#  'B000KXNYMS\n',
#  '  Books\n',
#  'B0000012DY\n',
#  '  Music, Country\n',
#  '  Music, Pop\n',
#  'B0000061PB\n',
#  '  Music, Classical\n',
#  '  Music, Pop\n',
#  'B000P9CMN4\n',
#  '  Grocery & Gourmet Food, Beverages, Soft Drinks\n',
#  'B000GAAIEM\n',
#  '  Home & Kitchen, Furniture, Other Furniture, Storage Chests\n',
#  'B0006EFBDG\n',
#  '  Books\n',
#  'B0000C2LFO\n',
#  '  Clothing & Accessories, Men, Tops & Tees, Polos\n',
#  '0965029824\n',
#  '  Books, Literature & Fiction, Genre Fiction, Action & Adventure\n',
#  '  Books, Travel, United States, West, Mountain\n',
#  'B000I82N6S\n',
#  '  Books\n',
#  'B0002DHR7Y\n',
#  '  Pet Supplies, Cats, Litter & Housebreaking, Litter\n',
#  'B0002XJVEG\n',
#  '  Home & Kitchen, Kitchen & Dining, Tabletop, Serveware, Teapots & Coffee Servers, Teapots\n',
#  'B0000C2LFK\n',
#  '  Clothing & Accessories, Men, Tops & Tees, Polos\n',
#  'B000B91KXG\n',
#  '  Beauty, Makeup, Face, Concealers & Neutralizers\n',
#  'B000BHQU7O\n',
#  '  Electronics, Portable Audio & Video, MP3 Players & Accessories, MP3 Players\n',
#  '0672324016\n',
#  '  Books, Computers & Technology, Digital Media Management, Video Production\n',
#  '  Books, Computers & Technology, Graphic Design\n',
#  '  Books, Computers & Technology, Programming, Graphics & Multimedia\n',
#  '  Books, Computers & Technology, Software\n',
#  '  Books, Computers & Technology, Web Development & Design, Web Design, Flash\n',
#  '  Books, Education & Reference, Foreign Language Study & Reference\n',
#  '  Books, New, Used & Rental Textbooks, Computer Science, Graphics & Visualization\n',
#  'B00004UAMB\n',
#  '  Music, Alternative Rock\n',
#  '  Music, Hard Rock & Metal\n',
#  '  Music, Pop\n',
#  '  Music, Rock\n',
#  'B00004UAMF\n',
#  '  Music, Dance & Electronic\n',
#  '  Music, Pop\n',
#  '  Music, Rap & Hip-Hop\n',
#  'B0000ZSKGQ\n',
#  '  Health & Personal Care, Medical Supplies & Equipment, Braces, Splints & Slings, Back & Shoulder\n',
#  '0964657406\n',
#  '  Books\n',
#  '031228117X\n',
#  '  Books, Biographies & Memoirs, People, A-Z, ( E ), Einstein, Albert\n',
#  '  Books, Biographies & Memoirs, Professionals & Academics, Scientists\n',
#  '  Books, New, Used & Rental Textbooks, Science & Mathematics\n',
#  '  Books, Science & Math, History & Philosophy\n',
#  '  Books, Science & Math, Technology\n',
#  'B000NJF81Y\n',
#  '  Books\n',
#  'B0002KZN2S\n',
#  '  Electronics, Camera & Photo, Accessories, Professional Video Accessories, Microphones\n',
#  '  Musical Instruments, Studio Recording Equipment, Microphones & Accessories, Bags & Cases\n',
#  'B0015MO3RI\n',
#  '  Movies & TV, Movies\n',
#  '0813807514\n',
#  '  Books, Education & Reference, Dictionaries & Thesauruses\n',
#  '  Books, Education & Reference, Schools & Teaching\n',
#  '  Books, Education & Reference, Writing, Research & Publishing Guides, Writing, Journalism & Nonfiction\n',
#  '  Books, New, Used & Rental Textbooks, Communication & Journalism, Journalism\n',
#  '  Books, New, Used & Rental Textbooks, Communication & Journalism, Media Studies\n',
#  '  Books, New, Used & Rental Textbooks, Humanities, Literature, Creative Writing & Composition\n',
#  '  Books, New, Used & Rental Textbooks, Social Sciences\n',
#  '  Books, Politics & Social Sciences, Social Sciences, Communication & Media Studies\n',
#  'B0000006Y9\n',
#  '  Music, Classical\n',
#  '0764552139\n',
#  '  Books, Computers & Technology\n',
#  '  Books, Education & Reference, Test Preparation, College & University, College Entrance\n',
#  '  Books, Health, Fitness & Dieting, Reference\n',
#  '  Books, Health, Fitness & Dieting, Safety & First Aid\n',
#  '  Books, New, Used & Rental Textbooks, Test Prep & Study Guides\n',
#  '  Books, Parenting & Relationships\n',
#  'B0009K4V1U\n',
#  '  Tools & Home Improvement, Power & Hand Tools, Measuring & Layout Tools, Levels\n',
#  '0345432134\n',
#  '  Books, Biographies & Memoirs, Ethnic & National, African-American & Black\n',
#  '  Books, Biographies & Memoirs, Memoirs\n',
#  '  Books, Biographies & Memoirs, Specific Groups, Women\n',
#  '  Books, Health, Fitness & Dieting, Mental Health, Depression\n',
#  '  Books, Health, Fitness & Dieting, Mental Health, Emotions\n',
#  '  Books, Health, Fitness & Dieting, Mental Health, Postpartum Depression\n',
#  '  Books, Health, Fitness & Dieting, Psychology & Counseling, Mental Illness\n',
#  '0613172329\n',
#  '  Books, Literature & Fiction, Genre Fiction, Historical\n',
#  '  Books, Literature & Fiction, Genre Fiction, Westerns\n',
#  '0060586885\n',
#  "  Books, Children's Books, Action & Adventure\n",
#  "  Books, Children's Books, Animals\n",
#  "  Books, Children's Books, Fairy Tales, Folk Tales & Myths, Dragons\n",
#  "  Books, Children's Books, Humor\n",
#  "  Books, Children's Books, Literature & Fiction\n",
#  "  Books, Children's Books, Science Fiction & Fantasy, Fantasy & Magic\n",
#  "  Books, Children's Books, Sports & Games, Activities & Toys\n",
#  'B00004UAMR\n',
#  '  Music, Pop\n',
#  '  Music, Rap & Hip-Hop\n',
#  'B00002SFLT\n',
#  '  Electronics, Television & Video, Satellite Television, Receivers\n',
#  'B000067J07\n',
#  '  Movies & TV, Movies\n',
#  'B0000006Y5\n',
#  '  Music, Classical\n',
#  'B000006X92\n',
#  '  Music, Hard Rock & Metal\n',
#  '  Music, Pop\n',
#  '  Music, Rock\n',
#  'B000H8RUXK\n',
#  '  Music, Pop\n',
#  '  Music, R&B\n',
#  'B0000006Y1\n',
#  '  Music, Classical\n',
#  '  Music, Dance & Electronic\n',
#  'B000JD2L3M\n',
#  '  Books\n',
#  '0205168388\n',
#  '  Books, Education & Reference, Foreign Language Study & Reference\n',
#  '  Books, Education & Reference, Writing, Research & Publishing Guides, Publishing & Books, Authorship\n',
#  '  Books, Education & Reference, Writing, Research & Publishing Guides, Writing, Academic & Commercial\n',
#  'B0006V0BAW\n',
#  '  Clothing & Accessories, Women, Intimates, Panties, G-Strings, Thongs & Tangas\n',
#  'B0000012DH\n',
#  '  Music, Pop\n',
#  '  Music, R&B\n',
#  '  Music, Rock\n',
#  'B004W706G0\n',
#  '  Amazon Instant Video\n',
#  'B000FN434G\n',
#  '  Industrial & Scientific, Hydraulics, Pneumatics & Plumbing, Tubing, Metal Tubing, Metal Industrial Wall Tubing\n',
#  '5557024050\n',
#  '  Books, Literature & Fiction, Short Stories, Anthologies\n',
#  'B0000012DL\n',
#  '  Music, Blues\n',
#  '  Music, Pop\n',
#  '  Music, Rock\n',
#  '091825969X\n',
#  '  Books, Humor & Entertainment, Humor, Parodies\n',
#  'B000H2M9W8\n',
#  '  Books\n',
#  '0688141323\n',
#  "  Books, Children's Books, Social Situations, Family Life, Multigenerational\n",
#  '0813531047\n',
#  '  Books, Arts & Photography, History & Criticism, Criticism\n',
#  '  Books, Business & Investing, Skills, Communications\n',
#  '  Books, Humor & Entertainment, Movies, History & Criticism\n',
#  '  Books, Humor & Entertainment, Television, History & Criticism\n',
#  '  Books, Politics & Social Sciences, Social Sciences, Specific Demographics, African-American Studies\n',
#  "  Books, Politics & Social Sciences, Women's Studies\n",
#  'B0007YMWCI\n',
#  '  Music, Dance & Electronic\n',
#  '  Music, Miscellaneous\n',
#  '  Music, Pop\n',
#  '  Musical Instruments, DJ, Electronic Music & Karaoke, Karaoke Equipment\n',
#  '0977312402\n',
#  '  Books, Self-Help, Self-Esteem\n',
#  '0006384226\n',
#  '  Books, Self-Help, Personal Transformation\n',
#  'B000HF0G2A\n',
#  '  Patio, Lawn & Garden, Mowers & Outdoor Power Tools, Outdoor Power Tool Accessories\n',
#  'B000GM830G\n',
#  '  Books, Literature & Fiction, Contemporary\n',
#  '0821755501\n',
#  '  Books, Literature & Fiction\n',
#  '  Books, Romance, Contemporary\n',
#  '  Books, Romance, Historical\n',
#  'B0000061PK\n',
#  '  Music, Dance & Electronic\n',
#  '  Music, Jazz\n',
#  '  Music, Pop\n',
#  '  Music, R&B\n',
#  'B00018RRRK\n',
#  '  Home & Kitchen, Kitchen & Dining, Coffee, Tea & Espresso, Coffee Grinders\n',
#  'B0027DQHAU\n',
#  '  Movies & TV, TV\n',
#  '  Music, Classical\n',
#  '0440229758\n',
#  '  Books, Teens\n',
#  'B0000061PO\n',
#  '  Music, Dance & Electronic\n',
#  '  Music, Miscellaneous\n',
#  '  Music, Pop\n',
#  '  Music, Rap & Hip-Hop\n',
#  'B0000012DP\n',
#  '  Music, Country\n',
#  '  Music, Folk\n',
#  '  Music, Pop\n',
#  '0953855422\n',
#  '  Books, Education & Reference, Encyclopedias, Antiques & Collectibles\n',
#  '  Books, Education & Reference, Foreign Language Study & Reference, Foreign Language Dictionaries & Thesauruses\n',
#  '1842180010\n',
#  '  Books, Business & Investing, Job Hunting & Careers, Guides\n',
#  '  Books, Business & Investing, Personal Finance\n',
#  '  Books, Self-Help, Success\n',
#  'B0000012DX\n',
#  '  Music, Country\n',
#  '  Music, Pop\n',
#  '  Music, Rock\n',
#  'B0000C2LFB\n',
#  '  Clothing & Accessories, Men, Tops & Tees, Polos\n',
#  'B007SUW1XE\n',
#  '  Movies & TV, Movies\n',
#  'B000JCQTEA\n',
#  '  Toys & Games, Hobbies, Radio Control, Boats & Watercraft\n',
#  'B0000C2LFF\n',
#  '  Clothing & Accessories, Men, Tops & Tees, Polos\n',
#  'B00009NRVY\n',
#  '  Music, Classic Rock\n',
#  '  Music, Folk\n',
#  '  Music, Pop\n',
#  '  Music, Rock\n',
#  'B0006ALJZ4\n',
#  '  Books\n',
#  'B0006F73AO\n',
#  '  Books\n',
#  'B000683TRC\n',
#  '  Music\n',
#  'B000KP1NEM\n',
#  '  Books\n',
#  '193183637X\n',
#  '  Books, Computers & Technology, Business & Management, Privacy\n',
#  '  Books, Computers & Technology, Hardware, Peripherals\n',
#  '  Books, Computers & Technology, Internet & Web Culture, Hacking\n',
#  '  Books, Computers & Technology, Mobile Phones, Tablets & E-Readers, Programming & App Development\n',
#  '  Books, Computers & Technology, Networking, Network Security\n',
#  '  Books, Computers & Technology, Networking, Networks, Protocols & APIs, LAN\n',
#  '  Books, Computers & Technology, Networking, Networks, Protocols & APIs, WAN\n',
#  '  Books, Computers & Technology, Security & Encryption\n',
#  '  Books, New, Used & Rental Textbooks, Computer Science, Networking\n',
#  '  Books, Professional & Technical, Engineering, Telecommunications\n',
#  'B000NBXCTM\n',
#  '  Electronics, Camera & Photo, Accessories, Photo Studio, Storage & Presentation Materials, Digital Picture Frames\n',
#  '0198532415\n',
#  '  Books, New, Used & Rental Textbooks, Science & Mathematics, Biology & Life Sciences, Biology\n',
#  '  Books, New, Used & Rental Textbooks, Science & Mathematics, Mathematics\n',
#  '  Books, Science & Math, Biological Sciences, Biology, Microbiology\n',
#  '  Books, Science & Math, Mathematics\n',
#  '  Books, Science & Math, Technology\n',
#  'B000FLLVCU\n',
#  '  Health & Personal Care, Nutrition & Wellness, Vitamins & Supplements, Fiber Supplements\n',
#  '  Health & Personal Care, Nutrition & Wellness, Vitamins & Supplements, Herbal Supplements\n',
#  'B00064KMMQ\n',
#  '  Shoes, Women\n',
#  'B00002SFLM\n',
#  '  Video Games, Mac, Games, Strategy\n',
#  'B00004UAMK\n',
#  '  Music, Alternative Rock\n',
#  '  Music, Blues\n',
#  '  Music, Pop\n',
#  '  Music, R&B\n',
#  '  Music, Rock\n',
#  '  Music, World Music\n',
#  'B0007F5MPQ\n',
#  '  Books\n',
#  '9992283076\n',
#  '  Books, Literature & Fiction, World Literature\n',
#  'B00002SFLE\n',
#  '  Video Games, PC, Games, Strategy\n',
#  '1893896056\n',
#  '  Books, Literature & Fiction, Contemporary\n',
#  '  Books, Romance, Fantasy & Futuristic\n',
#  '1562460897\n',
#  '  Books, Education & Reference, Schools & Teaching\n',
#  '  Books, Teens, Social Issues\n',
#  'B00004UAMC\n',
#  '  Music, Alternative Rock\n',
#  '  Music, Pop\n',
#  '  Music, Rock\n',
#  'B000GLKETK\n',
#  '  Books\n',
#  '0915643057\n',
#  '  Books, Literature & Fiction, Contemporary\n',
#  'B00004UAMG\n',
#  '  Music, Dance & Electronic\n',
#  '  Music, Pop\n',
#  '  Music, R&B\n',
#  'B00005UVWX\n',
#  '  Music, Classical\n',
#  '  Music, Miscellaneous\n',
#  'B00021W1D6\n',
#  '  Beauty, Makeup, Face, Blush\n',
#  '  Beauty, Makeup, Lips, Lipstick\n',
#  'B00002SFLA\n',
#  '  Video Games, PC, Games, Strategy\n',
#  'B0001KOBJ0\n',
#  '  Jewelry, Necklaces, Pendants\n',
#  'B00005UVWL\n',
#  '  Movies & TV, TV\n',
#  '  Music, Jazz\n',
#  'B00004UAMS\n',
#  '  Music, Pop\n',
#  '  Music, Rap & Hip-Hop\n',
#  'B000LNPS2G\n',
#  '  Cell Phones & Accessories, Unlocked Phones\n',
#  '0688036287\n',
#  '  Books, Health, Fitness & Dieting\n',
#  'B0000006Y4\n',
#  '  Music, Classical\n',
#  '1423319990\n',
#  '  Books, Literature & Fiction, Contemporary\n',
#  '  Books, Literature & Fiction, Humor\n',
#  '  Books, Literature & Fiction, United States, Humor\n',
#  'B000067J06\n',
#  '  Movies & TV, TV\n',
#  'B00002SFLU\n',
#  '  All Electronics\n',
#  'B000067J02\n',
#  '  Movies & TV, TV\n',
#  '  Music, Rock\n',
#  'B000GAQBTS\n',
#  '  Health & Personal Care, Nutrition & Wellness, Nutrition Bars & Drinks, Nutrition Bars\n',
#  'B0000006Y0\n',
#  '  Music, Classical\n',
#  '  Music, Miscellaneous\n',
#  'B0000006Y8\n',
#  '  Music, Classical\n',
#  '  Music, Miscellaneous\n',
#  'B00002SFLY\n',
#  '  Video Games, PC, Games, Puzzle\n',
#  '0631186719\n',
#  '  Books, History, Europe, France\n',
#  '  Books, History, Europe, Ireland\n',
#  '  Books, History, Europe, Western\n',
#  '  Books, History, Medieval\n',
#  '  Books, New, Used & Rental Textbooks, Humanities, History, Europe\n',
#  '1861002785\n',
#  '  Books, Computers & Technology, Hardware, Macs\n',
#  '  Books, Computers & Technology, Programming, Languages & Tools, Visual Basic\n',
#  '  Books, Education & Reference\n',
#  'B000ACM8F8\n',
#  '  Home & Kitchen, Bath, Bathroom Accessories\n',
#  'B0007DOALU\n',
#  "  Books, Children's Books\n",
#  'B0007ISLXI\n',
#  '  Books, Literature & Fiction, Contemporary\n',
#  '0941092356\n',
#  '  Books, Biographies & Memoirs, Professionals & Academics, Medical\n',
#  'B0000012D8\n',
#  '  Music, Pop\n',
#  '  Music, R&B\n',
#  'B000H7HB6M\n',
#  '  Books\n',
#  'B0001CHR12\n',
#  '  Automotive\n',
#  '0321021444\n',
#  '  Books, Literature & Fiction, Poetry\n',
#  'B0001GWB6E\n',
#  '  Music, Jazz\n',
#  '  Music, Pop\n',
#  '  Music, R&B\n',
#  '  Music, Rock\n',
#  'B0000012D4\n',
#  '  Music, Blues\n',
#  '  Music, Pop\n',
#  '  Music, R&B\n',
#  '  Music, Rock\n',
#  '0926842641\n',
#  '  Books, Education & Reference, Schools & Teaching, Instruction Methods\n',
#  '  Books, New, Used & Rental Textbooks, Education\n',
#  'B000HS0HTY\n',
#  '  Patio, Lawn & Garden, Generators & Portable Power, Generator Accessories\n',
#  '  Patio, Lawn & Garden, Mowers & Outdoor Power Tools, Outdoor Power Tools\n',
#  'B000MVVYEI\n',
#  '  Home & Kitchen, Furniture, Home Office Furniture, Home Office Desk Chairs\n',
#  '0198201842\n',
#  '  Books, Christian Books & Bibles, Protestantism, Anglican\n',
#  '  Books, Education & Reference, Schools & Teaching, Education Theory, Educational Psychology\n',
#  '  Books, Education & Reference, Words, Language & Grammar, Linguistics\n',
#  '  Books, History, Americas, United States\n',
#  '  Books, History, Modern (16th-21st Centuries), 16th Century\n',
#  '  Books, History, Modern (16th-21st Centuries), 17th Century\n',
#  '  Books, History, World, Religious, Christianity\n',
#  '  Books, New, Used & Rental Textbooks, Education\n',
#  '  Books, New, Used & Rental Textbooks, Humanities, History, United States\n',
#  '  Books, New, Used & Rental Textbooks, Humanities, Linguistics\n',
#  '  Books, New, Used & Rental Textbooks, Humanities, Religious Studies, Christianity\n',
#  'B0009RPPDQ\n',
#  '  Home & Kitchen, Vacuums & Floor Care, Vacuums, Canister Vacuums\n',
#  '  Industrial & Scientific, Janitorial & Sanitation Supplies, Floor Care, Vacuums, Indoor Vacuums, Canister Vacuums\n',
#  'B000CADCDA\n',
#  '  Music, Classic Rock\n',
#  '  Music, Pop\n',
#  '  Music, Rock\n',
#  'B000MSIO7G\n',
#  '  Grocery & Gourmet Food, Pantry Staples, Herbs, Spices & Seasonings, Pepper & Peppercorns, Peppercorns\n',
#  '1880684950\n',
#  '  Books, Literature & Fiction, Contemporary\n',
#  '  Books, Literature & Fiction, United States\n',
#  'B000PT25D6\n',
#  '  Electronics, Portable Audio & Video, MP3 Players & Accessories, MP3 Player Accessories, Cases\n',
#  'B000B9T17S\n',
#  '  Beauty, Hair Care, Shampoos\n',
#  'B0006PEDPW\n',
#  '  Books\n',
#  '0937539589\n',
#  '  Books, Business & Investing, Marketing & Sales, Sales & Selling\n',
#  '  Books, Business & Investing, Skills, Communications\n',
#  '  Books, Education & Reference, Words, Language & Grammar, Communication\n',
#  '  Books, Self-Help, Relationships, Interpersonal Relations\n',
#  'B0000DYJPK\n',
#  '  Clothing & Accessories, Women, Active, Active Pants\n',
#  '  Sports & Outdoors, Clothing, Women, Pants\n',
#  '155153777X\n',
#  '  Books, Crafts, Hobbies & Home, Pets & Animal Care, Cats\n',
#  '  Books, Science & Math, Biological Sciences, Animals\n',
#  '  Books, Science & Math, Nature & Ecology, Fauna\n',
#  'B0007D9MFE\n',
#  '  Music\n',
#  'B00002SFL5\n',
#  '  Software, Education & Reference\n',
#  '  Software, Language & Travel, Foreign Languages, Spanish\n',
#  '  Software, Language & Travel, Foreign Languages, Spanish & Portuguese\n',
#  'B000067J0V\n',
#  '  Movies & TV, Movies\n',
#  'B0000006YT\n',
#  '  Music, Classical\n',
#  '  Music, Miscellaneous\n',
#  'B00004UAM3\n',
#  '  Music, Dance & Electronic\n',
#  '  Music, Pop\n',
#  '  Music, Rap & Hip-Hop\n',
#  '0830715894\n',
#  '  Books, Christian Books & Bibles, Education\n',
#  '  Books, Education & Reference\n',
#  '  Books, Religion & Spirituality\n',
#  '  Books, Teens, Religion & Spirituality\n',
#  'B000B8FURY\n',
#  '  Shoes, Women, Sandals\n',
#  'B00004UAM7\n',
#  '  Music, Classic Rock\n',
#  '  Music, Hard Rock & Metal\n',
#  '  Music, Pop\n',
#  '  Music, Rock\n',
#  '4770024983\n',
#  '  Books, Education & Reference, Foreign Language Study & Reference, Foreign Language Dictionaries & Thesauruses\n',
#  '  Books, New, Used & Rental Textbooks, Humanities, Foreign Languages, Japanese\n',
#  'B000646U2M\n',
#  '  Patio, Lawn & Garden, Camp Chef\n',
#  '  Sports & Outdoors, Outdoor Recreation, Camping & Hiking, Camp Kitchen, Camp Stoves\n',
#  'B0000006YP\n',
#  '  Music, Classical\n',
#  'B000067J0R\n',
#  '  Movies & TV, Movies\n',
#  '1896761127\n',
#  '  Books, Literature & Fiction, Poetry\n',
#  'B000JR9YAG\n',
#  '  Books\n',
#  'B000067J0F\n',
#  '  Movies & TV, TV\n',
#  'B0000006YD\n',
#  '  Music, Christian\n',
#  '  Music, Classical\n',
#  '  Music, Miscellaneous\n',
#  '  Music, Pop\n',
#  '  Music, World Music\n',
#  'B000A48OSQ\n',
#  '  Music, Classic Rock\n',
#  '  Music, Folk\n',
#  '  Music, Miscellaneous\n',
#  '  Music, Pop\n',
#  '  Music, Rock\n',
#  '  Music, Soundtracks\n',
#  'B000PHS75S\n',
#  '  Sports & Outdoors, Cycling, Parts & Components, Saddles & Accessories, Saddles\n',
#  'B000FLGW7O\n',
#  '  Health & Personal Care, Nutrition & Wellness, Vitamins & Supplements, Fiber Supplements\n',
#  'B000MQFXKY\n',
#  '  Clothing & Accessories\n',
#  '1553064895\n',
#  '  Books, Literature & Fiction, Poetry\n',
#  '0471229717\n',
#  '  Books, Computers & Technology, Microsoft, Development, .NET\n',
#  '  Books, Computers & Technology, Programming, Introductory & Beginning\n',
#  '  Books, Computers & Technology, Programming, Languages & Tools, Visual Basic\n',
#  '  Books, Computers & Technology, Software\n',
#  '  Books, Education & Reference\n',
#  '  Books, New, Used & Rental Textbooks, Computer Science, Programming Languages\n',
#  '2226088490\n',
#  '  Books\n',
#  'B0000006YH\n',
#  '  Music, Christian\n',
#  '  Music, Classical\n',
#  '  Music, Dance & Electronic\n',
#  '  Music, Miscellaneous\n',
#  'B000BRPB9C\n',
#  '  Books\n',
#  'B000006X9K\n',
#  '  Music, Latin Music\n',
#  '  Music, World Music\n',
#  'B000065RZC\n',
#  '  Movies & TV, Movies\n',
#  'B000C9RKFC\n',
#  '  Health & Personal Care, Sexual Wellness, Adult Toys & Games, Sex Toys, Vibrators\n',
#  'B000CB055C\n',
#  '  Automotive, Replacement Parts, Ignition Parts, Distributors & Parts, Distributor Caps\n',
#  'B000067J0N\n',
#  '  Movies & TV, Movies\n',
#  '0932750435\n',
#  '  Books, Business & Investing, Investing, Stocks\n',
#  '0471350850\n',
#  '  Books, Business & Investing, Investing\n',
#  '  Books, Business & Investing, Small Business & Entrepreneurship, Entrepreneurship\n',
#  '  Books, New, Used & Rental Textbooks, Business & Finance, Economics\n',
#  '  Books, New, Used & Rental Textbooks, Business & Finance, Entrepreneurship\n',
#  '  Books, New, Used & Rental Textbooks, Business & Finance, Investments & Securities\n',
#  'B000O0A5R4\n',
#  '  Books\n',
#  'B000IDMTI0\n',
#  '  Toys & Games, Games\n',
#  'B000A7QOOY\n',
#  '  Sports & Outdoors, Cycling, Tires & Tubes, Tires\n',
#  'B0000061PM\n',
#  '  Music, Dance & Electronic\n',
#  '  Music, Miscellaneous\n',
#  '  Music, Pop\n',
#  '  Music, Rap & Hip-Hop\n',
#  '  Music, Rock\n',
#  'B0004EAFWK\n',
#  '  Toys & Games, Grown-Up Toys, Hobbies\n',
#  '  Toys & Games, Hobbies, Model Building Kits & Tools, Figures\n',
#  'B00024YAO6\n',
#  '  Books, Biographies & Memoirs, Historical, United States\n',
#  '  Books, Biographies & Memoirs, Leaders & Notable People, Political\n',
#  'B000NPVN5I\n',
#  '  Books, Literature & Fiction, Genre Fiction, Westerns\n',
#  'B000C9WJRG\n',
#  '  Automotive, Replacement Parts, Fuel System, Fuel Pumps & Accessories, Filters\n',
#  '0435272640\n',
#  '  Books, Education & Reference, Schools & Teaching\n',
#  '  Books, Teens, Education & Reference, Language Arts\n',
#  'B0002052F6\n',
#  '  Shoes, Women, Fashion Sneakers\n',
#  'B0000061PE\n',
#  '  Music, Jazz\n',
#  '  Music, Pop\n',
#  'B000Q9N2M8\n',
#  '  Grocery & Gourmet Food, Meat & Poultry, Jerky\n',
#  '0452274982\n',
#  '  Books, Gay & Lesbian, Literature & Fiction, Fiction, Gay\n',
#  '  Books, Literature & Fiction, Contemporary\n',
#  '  Books, Literature & Fiction, Genre Fiction, Family Saga\n',
#  '  Books, Literature & Fiction, United States\n',
#  'B000HBAIK4\n',
#  '  Tools & Home Improvement, Power & Hand Tools, Hand Tools, Wrench Sets\n',
#  'B0000012DJ\n',
#  '  Music, Pop\n',
#  '  Music, R&B\n',
#  'B0006WMB36\n',
#  '  Books\n',
#  'B000JJI20M\n',
#  '  Books\n',
#  'B000OVJ9OS\n',
#  '  Books\n',
#  'B000KWIE7Y\n',
#  '  Books\n',
#  'B000HMGB90\n',
#  '  Books\n',
#  'B0002QNNP6\n',
#  '  Beauty, Makeup, Nails, Nail Polish\n',
#  'B0000A0QEE\n',
#  '  Clothing & Accessories, Men, Tops & Tees, Dress Shirts\n',
#  'B000AA4MTK\n',
#  '  Jewelry, Novelty Jewelry, Body Jewelry, Piercing Jewelry, Rings\n',
#  'B0000012DF\n',
#  '  Music, Pop\n',
#  '  Music, R&B\n',
#  '  Music, Rock\n',
#  'B000XPT3PK\n',
#  '  Movies & TV, Movies\n',
#  'B0000012DB\n',
#  '  Music, Blues\n',
#  '  Music, Pop\n',
#  '  Music, R&B\n',
#  'B0000C2LFX\n',
#  '  Clothing & Accessories, Men, Tops & Tees, Polos\n',
#  '0394578058\n',
#  '  Books, Literature & Fiction, Mythology & Folk Tales, Mythology\n',
#  '  Books, Politics & Social Sciences, Anthropology, Cultural\n',
#  '  Books, Science & Math, Technology\n',
#  '630404934X\n',
#  '  Movies & TV, Movies\n',
#  'B0009F9MRI\n',
#  '  Tools & Home Improvement, Power & Hand Tools, Measuring & Layout Tools, Line Lasers\n',
#  '  Tools & Home Improvement, Power & Hand Tools, Measuring & Layout Tools, Rotary Lasers\n',
#  '0426202546\n',
#  '  Books, Literature & Fiction\n',
#  '  Books, Science Fiction & Fantasy, Science Fiction\n',
#  'B00004UAMQ\n',
#  '  Music, Pop\n',
#  '  Music, Rap & Hip-Hop\n',
#  'B0001FF824\n',
#  '  Clothing & Accessories, Luggage & Bags, Travel Accessories\n',
#  'B000067J04\n',
#  '  Movies & TV, TV\n',
#  'B0000006Y6\n',
#  '  Music, Classical\n',
#  'B000067J00\n',
#  '  Movies & TV, Movies\n',
#  '0671731084\n',
#  '  Books, Teens, Mysteries\n',
#  'B000006X99\n',
#  '  Music, Dance & Electronic\n',
#  '  Music, Pop\n',
#  '1593372302\n',
#  '  Books, Crafts, Hobbies & Home, Crafts & Hobbies, Decorating\n',
#  'B000067J08\n',
#  '  Movies & TV, TV\n',
#  '  Music, Alternative Rock\n',
#  '  Music, Hard Rock & Metal\n',
#  '  Music, Pop\n',
#  '  Music, Rock\n',
#  'B0006EEFYM\n',
#  '  Books, New, Used & Rental Textbooks\n',
#  '0931104165\n',
#  '  Books\n',
#  'B000IN1N9Q\n',
#  '  Clothing & Accessories, Novelty & Special Use, Novelty, Socks\n',
#  'B000EY3JDW\n',
#  '  Health & Personal Care, Sexual Wellness, Safer Sex, Condoms\n',
#  'B001UYZ5QY\n',
#  '  Amazon Instant Video\n',
#  'B00004UAMM\n',
#  '  Music, Pop\n',
#  '  Music, Rap & Hip-Hop\n',
#  '0439281334\n',
#  "  Books, Children's Books, Literature & Fiction, Historical Fiction, Europe\n",
#  "  Books, Children's Books, Social Situations, Friendship\n",
#  "  Books, Children's Books, Social Situations, Self-Esteem & Self-Respect\n",
#  "  Books, Children's Books, Social Situations, Values\n",
#  'B00002SFLK\n',
#  '  Video Games, PC, Games, Strategy\n',
#  'B000J54S18\n',
#  '  Books\n',
#  'B00002SFLO\n',
#  '  Video Games, PC, Games, Strategy\n',
#  'B000JSVY3A\n',
#  '  Sports & Outdoors, Fan Shop, Clothing, Sweatshirts\n',
#  'B0002IXS1I\n',
#  '  Tools & Home Improvement, Power & Hand Tools, Hand Tools, Cutters, Wire Cutters\n',
#  'B000GLKETA\n',
#  '  Books\n',
#  '0821777017\n',
#  '  Books, Literature & Fiction, Genre Fiction, Historical\n',
#  '  Books, Literature & Fiction, United States\n',
#  '  Books, Romance, Historical\n',
#  '6304060424\n',
#  '  Movies & TV, Movies\n',
#  '096393290X\n',
#  '  Books, Education & Reference, Words, Language & Grammar, Linguistics\n',
#  'B000I5ZUJI\n',
#  '  Beauty, Skin Care, Sets\n',
#  'B00004UAMA\n',
#  '  Music, Alternative Rock\n',
#  '  Music, Pop\n',
#  '  Music, Rock\n',
#  'B000LTVD5Q\n',
#  '  Clothing & Accessories\n',
#  'B00004UAME\n',
#  '  Music, Alternative Rock\n',
#  '  Music, Dance & Electronic\n',
#  '  Music, Pop\n',
#  '  Music, Rock\n',
#  'B000BIBF46\n',
#  '  Electronics, Computers & Accessories, Computer Components\n',
#  '  Tools & Home Improvement, Power & Hand Tools, Hand Tools, Screwdrivers\n',
#  'B00002SFLC\n',
#  '  Video Games, PC, Games, Strategy\n',
#  'B0000061P9\n',
#  '  Music, Classical\n',
#  '  Music, Miscellaneous\n',
#  '  Music, Pop\n',
#  '0870405187\n',
#  '  Books, Crafts, Hobbies & Home, Crafts & Hobbies, Toys & Models, Miniatures\n',
#  'B000KT5DGC\n',
#  '  Books\n',
#  'B000FBHCLE\n',
#  '  Movies & TV, Movies\n',
#  'B00007GXIL\n',
#  '  Music, Folk\n',
#  '  Music, Latin Music\n',
#  '  Music, Miscellaneous\n',
#  '  Music, Pop\n',
#  '  Music, World Music\n',
#  'B000BQN5YG\n',
#  '  Video Games, More Systems, PlayStation 2, Hardware, Accessories\n',
#  'B000BRIKWW\n',
#  '  Music, Pop\n',
#  '  Music, Rock\n',
#  '0890878897\n',
#  '  Books, Religion & Spirituality, Buddhism\n',
#  '  Books, Religion & Spirituality, Occult\n',
#  'B0000061P5\n',
#  '  Music, Classical\n',
#  '0764530623\n',
#  '  Books, Computers & Technology, Networking\n',
#  '  Books, Computers & Technology, Programming, Languages & Tools\n',
#  '  Books, Computers & Technology, Software\n',
#  '  Books, Education & Reference\n',
#  '  Books, Science & Math, Mathematics\n',
#  'B0006FKVZS\n',
#  '  Watches, Wrist Watches\n',
#  'B0001GWB6O\n',
#  '  Movies & TV, TV\n',
#  '  Music, Pop\n',
#  '  Music, Rap & Hip-Hop\n',
#  '0521567343\n',
#  '  Books, Education & Reference, Schools & Teaching, Instruction Methods\n',
#  '  Books, History, Europe, France\n',
#  '  Books, History, Europe, Ireland\n',
#  '  Books, History, Military\n',
#  '  Books, Teens, Education & Reference, History\n',
#  '0380790513\n',
#  '  Books, Crafts, Hobbies & Home, Pets & Animal Care, Cats\n',
#  '0967748003\n',
#  '  Books\n',
#  'B0053XZ94G\n',
#  '  Movies & TV, Movies\n',
#  'B0000012D6\n',
#  '  Music, Blues\n',
#  '  Music, Pop\n',
#  'B0006B9860\n',
#  '  Music, Pop\n',
#  '  Music, Rock\n',
#  '0761119884\n',
#  '  Books, Education & Reference, Test Preparation, College & University, SAT & PSAT\n',
#  'B000BV7MSQ\n',
#  '  Electronics, Computers & Accessories\n',
#  '0966808401\n',
#  '  Books, Education & Reference, Consumer Guides\n',
#  '  Books, Self-Help\n',
#  'B0000012D2\n',
#  '  Music, Blues\n',
#  '  Music, Jazz\n',
#  '  Music, Pop\n',
#  '  Music, R&B\n',
#  '0789208695\n',
#  '  Books, Arts & Photography, Photography, Equipment, Techniques & Reference\n',
#  '  Books, Arts & Photography, Photography, Travel\n',
#  '  Books, Education & Reference, Writing, Research & Publishing Guides, Writing, Travel\n',
#  '  Books, Travel, Asia, General\n',
#  '  Books, Travel, Reference, General\n',
#  ...]

# %%
index = 0
while True:
    if arr[index + 1][0] == ' ' and arr[index][0] != ' ':
        prods.append(arr[index])
        i = 0
    else:
        if i == 0:
            categories.append(row[2:])
            i += 1

        

file.close()

df_cats = pd.DataFrame({'ProductId': prods, 'Categories': categories})

df_cats.head()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10964/3924577914.py in <module>
#       2 while True:
#       3     if arr[index + 1][0] == ' ' and arr[index][0] != ' ':
# ----> 4         prods.append(arr[index])
#       5         i = 0
#       6     else:
#
# MemoryError:
